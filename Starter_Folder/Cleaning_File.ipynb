# %%
# Data for Hospitals
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = "../Resources/healthcare_dataset.csv"
hospital_df = pd.read_csv(file)
hospital_df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0    18856.281306          328         Urgent     2024-02-02  Paracetamol
# 1    33643.327287          265      Emergency     2019-08-26    Ibuprofen
# 2    27955.096079          205      Emergency     2022-10-07      Aspirin
# 3    37909.782410          450       Elective     2020-12-18    Ibuprofen
# 4    14238.317814          458         Urgent     2022-10-09   Penicillin
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal

# %%
def isCurrent(date_string):
    year = date_string[0:4]
    if year == "2024":
        return True
    else:
        return False

# %% [markdown]
# ## Testing code example. Check all cases.

# %%
# year test
isCurrent("2024")
# Out:
# True

# %%
#false year test
isCurrent("2023")
# Out:
# False

# %%
# check year-month test
isCurrent("2024-01")
# Out:
# True

# %%
isCurrent("2022-01")
# Out:
# False

# %%
# check year-month-day test
isCurrent("2024-01-31")
# Out:
# True

# %%
isCurrent("2021-01-31")
# Out:
# False

# %%
'''try:
    if year:
        if year-month:
            if year-month-day:
            else:
                failed
        else:
            failed 
    else:
        failed
except:
'''
# Out:
# 'try:\n    if year:\n        if year-month:\n            if year-month-day:\n            else:\n                failed\n        else:\n            failed \n    else:\n        failed\nexcept:\n'

# %%
'''original datatypes'''
hospital_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 6.4+ MB

# %%
'''Change Date of Admission and Discharge Date to date_time ''' 
hospital_df['Date of Admission'] = pd.to_datetime(hospital_df['Date of Admission'])
hospital_df['Discharge Date'] = pd.to_datetime(hospital_df['Discharge Date'])

# %%
''' Filter out 2024 Dates'''
hospital_df_2024 = hospital_df[hospital_df['Date of Admission'].dt.year == 2024]

hospital_df_2024.head(5)
# Out:
#               Name  Age Gender Blood Type Medical Condition Date of Admission  \
# 0    Bobby JacksOn   30   Male         B-            Cancer        2024-01-31
# 50     mIchael LiU   30   Male        AB-      Hypertension        2024-04-05
# 61       Kim ScOtt   63   Male         A-            Asthma        2024-04-07
# 68  MicHAEl MillEr   31   Male         B+          Diabetes        2024-02-06
# 79   tiMOThY myers   61   Male         B+            Cancer        2024-03-02
#
#             Doctor                       Hospital Insurance Provider  \
# 0    Matthew Smith                Sons and Miller         Blue Cross
# 50    Vicki Nguyen  Fernandez and Phillips, Singh           Medicare
# 61     Cindy Ellis                    Scott-Kelly   UnitedHealthcare
# 68  Jonathan Drake         Clark Brown, and Myers   UnitedHealthcare
# 79   Timothy Baker                 and Sons Reyes   UnitedHealthcare
#
#     Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0     18856.281306          328         Urgent     2024-02-02  Paracetamol
# 50    30590.541806          456      Emergency     2024-04-22  Paracetamol
# 61    39723.166051          244      Emergency     2024-05-04    Ibuprofen
# 68    35776.815111          489      Emergency     2024-02-10   Penicillin
# 79    29504.387442          422         Urgent     2024-03-26    Ibuprofen
#
#     Test Results
# 0         Normal
# 50  Inconclusive
# 61  Inconclusive
# 68        Normal
# 79  Inconclusive

# %%
''' Checking new data types'''
hospital_df_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3854 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                3854 non-null   object
#  1   Age                 3854 non-null   int64
#  2   Gender              3854 non-null   object
#  3   Blood Type          3854 non-null   object
#  4   Medical Condition   3854 non-null   object
#  5   Date of Admission   3854 non-null   datetime64[ns]
#  6   Doctor              3854 non-null   object
#  7   Hospital            3854 non-null   object
#  8   Insurance Provider  3854 non-null   object
#  9   Billing Amount      3854 non-null   float64
#  10  Room Number         3854 non-null   int64
#  11  Admission Type      3854 non-null   object
#  12  Discharge Date      3854 non-null   datetime64[ns]
#  13  Medication          3854 non-null   object
#  14  Test Results        3854 non-null   object
# dtypes: datetime64[ns](2), float64(1), int64(2), object(10)
# memory usage: 481.8+ KB

# %%
''' Can't Groupby without aggregate (ex: count(), mean(), median())'''
# tries to print but does not.
hospital_df_2024.groupby('Hospital')

# %%
# how to set column 'Hospital' as the index but it removes the previous index
hospital_df_2024.set_index('Hospital').head()
# Out:
#                                          Name  Age Gender Blood Type  \
# Hospital
# Sons and Miller                 Bobby JacksOn   30   Male         B-
# Fernandez and Phillips, Singh     mIchael LiU   30   Male        AB-
# Scott-Kelly                         Kim ScOtt   63   Male         A-
# Clark Brown, and Myers         MicHAEl MillEr   31   Male         B+
# and Sons Reyes                  tiMOThY myers   61   Male         B+
#
#                               Medical Condition Date of Admission  \
# Hospital
# Sons and Miller                          Cancer        2024-01-31
# Fernandez and Phillips, Singh      Hypertension        2024-04-05
# Scott-Kelly                              Asthma        2024-04-07
# Clark Brown, and Myers                 Diabetes        2024-02-06
# and Sons Reyes                           Cancer        2024-03-02
#
#                                        Doctor Insurance Provider  \
# Hospital
# Sons and Miller                 Matthew Smith         Blue Cross
# Fernandez and Phillips, Singh    Vicki Nguyen           Medicare
# Scott-Kelly                       Cindy Ellis   UnitedHealthcare
# Clark Brown, and Myers         Jonathan Drake   UnitedHealthcare
# and Sons Reyes                  Timothy Baker   UnitedHealthcare
#
#                                Billing Amount  Room Number Admission Type  \
# Hospital
# Sons and Miller                  18856.281306          328         Urgent
# Fernandez and Phillips, Singh    30590.541806          456      Emergency
# Scott-Kelly                      39723.166051          244      Emergency
# Clark Brown, and Myers           35776.815111          489      Emergency
# and Sons Reyes                   29504.387442          422         Urgent
#
#                               Discharge Date   Medication  Test Results
# Hospital
# Sons and Miller                   2024-02-02  Paracetamol        Normal
# Fernandez and Phillips, Singh     2024-04-22  Paracetamol  Inconclusive
# Scott-Kelly                       2024-05-04    Ibuprofen  Inconclusive
# Clark Brown, and Myers            2024-02-10   Penicillin        Normal
# and Sons Reyes                    2024-03-26    Ibuprofen  Inconclusive

# %%
# as an example when chaining .set_index() we lose the previous column 'Hospital'
hospital_df_2024.set_index('Hospital').set_index('Doctor').head()
# Out:
#                           Name  Age Gender Blood Type Medical Condition  \
# Doctor
# Matthew Smith    Bobby JacksOn   30   Male         B-            Cancer
# Vicki Nguyen       mIchael LiU   30   Male        AB-      Hypertension
# Cindy Ellis          Kim ScOtt   63   Male         A-            Asthma
# Jonathan Drake  MicHAEl MillEr   31   Male         B+          Diabetes
# Timothy Baker    tiMOThY myers   61   Male         B+            Cancer
#
#                Date of Admission Insurance Provider  Billing Amount  \
# Doctor
# Matthew Smith         2024-01-31         Blue Cross    18856.281306
# Vicki Nguyen          2024-04-05           Medicare    30590.541806
# Cindy Ellis           2024-04-07   UnitedHealthcare    39723.166051
# Jonathan Drake        2024-02-06   UnitedHealthcare    35776.815111
# Timothy Baker         2024-03-02   UnitedHealthcare    29504.387442
#
#                 Room Number Admission Type Discharge Date   Medication  \
# Doctor
# Matthew Smith           328         Urgent     2024-02-02  Paracetamol
# Vicki Nguyen            456      Emergency     2024-04-22  Paracetamol
# Cindy Ellis             244      Emergency     2024-05-04    Ibuprofen
# Jonathan Drake          489      Emergency     2024-02-10   Penicillin
# Timothy Baker           422         Urgent     2024-03-26    Ibuprofen
#
#                 Test Results
# Doctor
# Matthew Smith         Normal
# Vicki Nguyen    Inconclusive
# Cindy Ellis     Inconclusive
# Jonathan Drake        Normal
# Timothy Baker   Inconclusive

# %%
# shows that variable hospital_df_2024 is unmutated by previous function.
# use inplace=True flag to mutate variable or store changes in new variable. 
hospital_df_2024.head()
# Out:
#               Name  Age Gender Blood Type Medical Condition Date of Admission  \
# 0    Bobby JacksOn   30   Male         B-            Cancer        2024-01-31
# 50     mIchael LiU   30   Male        AB-      Hypertension        2024-04-05
# 61       Kim ScOtt   63   Male         A-            Asthma        2024-04-07
# 68  MicHAEl MillEr   31   Male         B+          Diabetes        2024-02-06
# 79   tiMOThY myers   61   Male         B+            Cancer        2024-03-02
#
#             Doctor                       Hospital Insurance Provider  \
# 0    Matthew Smith                Sons and Miller         Blue Cross
# 50    Vicki Nguyen  Fernandez and Phillips, Singh           Medicare
# 61     Cindy Ellis                    Scott-Kelly   UnitedHealthcare
# 68  Jonathan Drake         Clark Brown, and Myers   UnitedHealthcare
# 79   Timothy Baker                 and Sons Reyes   UnitedHealthcare
#
#     Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0     18856.281306          328         Urgent     2024-02-02  Paracetamol
# 50    30590.541806          456      Emergency     2024-04-22  Paracetamol
# 61    39723.166051          244      Emergency     2024-05-04    Ibuprofen
# 68    35776.815111          489      Emergency     2024-02-10   Penicillin
# 79    29504.387442          422         Urgent     2024-03-26    Ibuprofen
#
#     Test Results
# 0         Normal
# 50  Inconclusive
# 61  Inconclusive
# 68        Normal
# 79  Inconclusive

# %%
# we got rid of columns 'Room Number' and "Medication' using drop() function
# axis = 1 is vertical direction for columns. 
hospital_df_2024_drop = hospital_df_2024.drop(['Room Number', 'Medication'], axis=1)
hospital_df_2024_drop.head()
# Out:
#               Name  Age Gender Blood Type Medical Condition Date of Admission  \
# 0    Bobby JacksOn   30   Male         B-            Cancer        2024-01-31
# 50     mIchael LiU   30   Male        AB-      Hypertension        2024-04-05
# 61       Kim ScOtt   63   Male         A-            Asthma        2024-04-07
# 68  MicHAEl MillEr   31   Male         B+          Diabetes        2024-02-06
# 79   tiMOThY myers   61   Male         B+            Cancer        2024-03-02
#
#             Doctor                       Hospital Insurance Provider  \
# 0    Matthew Smith                Sons and Miller         Blue Cross
# 50    Vicki Nguyen  Fernandez and Phillips, Singh           Medicare
# 61     Cindy Ellis                    Scott-Kelly   UnitedHealthcare
# 68  Jonathan Drake         Clark Brown, and Myers   UnitedHealthcare
# 79   Timothy Baker                 and Sons Reyes   UnitedHealthcare
#
#     Billing Amount Admission Type Discharge Date  Test Results
# 0     18856.281306         Urgent     2024-02-02        Normal
# 50    30590.541806      Emergency     2024-04-22  Inconclusive
# 61    39723.166051      Emergency     2024-05-04  Inconclusive
# 68    35776.815111      Emergency     2024-02-10        Normal
# 79    29504.387442         Urgent     2024-03-26  Inconclusive

# %%
counts = hospital_df["Insurance Provider"].value_counts()
counts
# Out:
# Insurance Provider
# Cigna               11249
# Medicare            11154
# UnitedHealthcare    11125
# Blue Cross          11059
# Aetna               10913
# Name: count, dtype: int64

# %%
## Generate a pie chart, using Pandas, showing the distribution of Insurance provider used in the study

plt.pie(
   counts.values,
   labels=counts.index.values,
    autopct="%1.1f%%",
   
)
plt.title, 
# Get the distribution of Insurance provider used in the study
counts = hospital_df["Insurance Provider"].value_counts()
counts
# Make the pie chart
plt.show()

# %%
# Group by hospital and sum billing costs
hospital_billing = hospital_df_2024_drop.groupby("Insurance Provider" )["Billing Amount"].sum()

# Sort values and select top 10
#top_insurance = hospital_billing.sort_values(ascending=False).head(10)

# Create a bar plot
top_hospitals.plot(kind="bar", title="Total Billing Costs by Insurance Cost", xlabel="Hospital", ylabel="Billing Amount")
plt.show()
